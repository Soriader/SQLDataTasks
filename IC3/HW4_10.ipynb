# %%
# %pip install "pyarrow>=15.0.0"
import os
import time
import pyspark.pandas as ps


os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

from pyspark.sql import SparkSession
import pyspark.pandas as ps

spark = (
    SparkSession.builder
    .appName("HW4.10 Pandas API on Spark")
    .getOrCreate()
)

start = time.perf_counter()

df = ps.read_csv("sample_orders.csv")

df["placed_at"] = ps.to_datetime(df["placed_at"])

df["revenue"] = df["quantity"] * df["price_each"]

df["month"] = df["placed_at"].dt.strftime("%Y-%m")

paid = df[df["status"] == "paid"]

monthly = (
    paid.groupby(["country", "month"])["revenue"]
    .sum()
    .reset_index()
    .sort_values(["country", "month"])
)

print(monthly.head(20))

end = time.perf_counter()

print(f"Elapsed time: {end - start:.4f} seconds")
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-24.0.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Downloading pyarrow-24.0.0-cp313-cp313-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/27.3 MB 5.9 MB/s eta 0:00:05
#    -- ------------------------------------- 1.8/27.3 MB 3.9 MB/s eta 0:00:07
#    --- ------------------------------------ 2.1/27.3 MB 3.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.9/27.3 MB 4.4 MB/s eta 0:00:06
#    ------ --------------------------------- 4.7/27.3 MB 4.5 MB/s eta 0:00:05
#    --------- ------------------------------ 6.6/27.3 MB 4.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 7.3/27.3 MB 4.9 MB/s eta 0:00:05
#    ------------- -------------------------- 8.9/27.3 MB 5.1 MB/s eta 0:00:04
#    -------------- ------------------------- 10.0/27.3 MB 5.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.3/27.3 MB 5.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.3/27.3 MB 5.3 MB/s eta 0:00:04
#    ------------------ --------------------- 12.3/27.3 MB 5.0 MB/s eta 0:00:04
#    ------------------- -------------------- 13.4/27.3 MB 4.8 MB/s eta 0:00:03
#    -------------------- ------------------- 13.9/27.3 MB 4.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 15.2/27.3 MB 4.8 MB/s eta 0:00:03
#    ------------------------ --------------- 16.5/27.3 MB 4.8 MB/s eta 0:00:03
#    -------------------------- ------------- 17.8/27.3 MB 4.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.1/27.3 MB 5.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.2/27.3 MB 5.1 MB/s eta 0:00:02
#    ------------------------------- -------- 21.5/27.3 MB 5.1 MB/s eta 0:00:02
#    --------------------------------- ------ 22.5/27.3 MB 5.1 MB/s eta 0:00:01
#    --------------------------------- ------ 23.1/27.3 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 24.6/27.3 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 25.7/27.3 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  26.7/27.3 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-24.0.0
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 get_ipython().run_line_magic('pip', 'install "pyarrow>=15.0.0"')
#       2 import os
#       3 import time
# ----> 4 import pyspark.pandas as ps
#       5
#       6
#       7 os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
#
# File ~\PycharmProjects\SQLDataTasks\.venv\Lib\site-packages\pyspark\pandas\__init__.py:59
#      57 from pyspark.pandas.indexes.timedelta import TimedeltaIndex
#      58 from pyspark.pandas.series import Series
# ---> 59 from pyspark.pandas.groupby import NamedAgg
#      61 __all__ = [  # noqa: F405
#      62     "read_csv",
#      63     "read_parquet",
#    (...)     87     "NamedAgg",
#      88 ]
#      91 def _auto_patch_spark() -> None:
#
# File ~\PycharmProjects\SQLDataTasks\.venv\Lib\site-packages\pyspark\pandas\groupby.py:48
#      46 import pandas as pd
#      47 from pandas.api.types import is_number, is_hashable, is_list_like  # type: ignore[attr-defined]
# ---> 48 from pandas.core.common import _builtin_table  # type: ignore[attr-defined]
#      50 from pyspark.sql import Column, DataFrame as SparkDataFrame, Window, functions as F
#      51 from pyspark.sql.internal import InternalFunction as SF
#
# ImportError: cannot import name '_builtin_table' from 'pandas.core.common' (C:\Users\ROG\PycharmProjects\SQLDataTasks\.venv\Lib\site-packages\pandas\core\common.py)
